# %% [markdown]
# ## Processing of Job Descriptions Required Education
#
# Goal:</br>
# Transform the single variable 'required_education' to two variables 'required_education_level' 'required_education_field'
#
# Assumtions:</br>
# - Choose education level based on lowest level referred to (e.g. bachelor required, master preferred --> bachelor)
# - something else?

# %%
# Initialisation
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql import functions as F
from pyspark.sql import types as T

from utils.spark_utils import pyspark_df_info

# %%
spark = SparkSession.builder \
    .appName("Silver Processing Education") \
    .master("local[*]") \
    .getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# 25/06/19 11:38:34 WARN Utils: Your hostname, Nicholass-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.1.45 instead (on interface en0)
# 25/06/19 11:38:34 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/06/19 11:38:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Loading data 
df = spark.read.parquet('data/silver/*.parquet')
pyspark_df_info(df)
# Out:
# Total entries: 6241
# Data columns (total 32 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   resume_id                 6241               string
# 1   job_id                    6241               string
# 2   _id                       6241               string
# 3   fit                       6241               string
# 4   snapshot_date             6241               date
# 5   fit_score                 6241               double
# 6   company_name              3908               string
# 7   role_title                6046               string
# 8   employment_type           6196               string
# 9   job_location              4075               string
# 10  about_the_company         3664               string
# 11  job_responsibilities      6241               array<string>
# 12  required_hard_skills      6241               array<string>
# 13  required_soft_skills      6241               array<string>
# 14  required_language_proficiencies 6241               array<string>
# 15  required_education        4378               string
# 16  required_work_authorization 1141               string
# 17  jd_certifications         6241               array<string>
# 18  job_snapshot              6241               date
# 19  name                      237                string
# 20  location_preference       146                string
# 21  work_authorization        131                string
# 22  employment_type_preference 304                string
# 23  hard_skills               6241               array<string>
# 24  soft_skills               6241               array<string>
# 25  languages                 6241               array<string>
# 26  experience                6241               array<struct<role:string,company:string,date_start:string,date_end:string,role_description:string,snapshot_date:string,id:string>>
# 27  education                 6241               array<struct<degree:string,institution:string,date_start:string,date_end:string,grade:double,description:string,snapshot_date:string,id:string>>
# 28  resume_certifications     6241               array<string>
# 29  resume_snapshot           6241               string
# 30  YoE                       6126               float
# 31  exp_sim                   6241               float

# %%
# Filtering to relevant columns & removing null values
df_education = df['job_id', '_id', 'snapshot_date', 'job_snapshot', 'required_education']
df_education.show(5, truncate=False)
print(f"Total records: {df_education.count()}")

df_education = df_education.filter(F.col('required_education').isNotNull())
print(f"Records after filtering nulls: {df_education.count()}")
# Out:
# +-----------+------------------------+-------------+------------+--------------------------------------------------------------------------------------------------+
# |job_id     |_id                     |snapshot_date|job_snapshot|required_education                                                                                |
# +-----------+------------------------+-------------+------------+--------------------------------------------------------------------------------------------------+
# |JD_s93wTCLp|6845479b07df3572368fc32c|2021-07-15   |2021-07-15  |NULL                                                                                              |
# |JD_Z7yf1tu6|684547e670634603a66d8deb|2021-07-24   |2021-07-24  |Bachelor's degree in computer science or a related discipline required. Master's degree preferred.|
# |JD_hAp1XnJZ|684547ed70634603a66d8def|2021-07-21   |2021-07-21  |NULL                                                                                              |
# |JD_zsgGxd2s|684547f370634603a66d8df3|2021-07-30   |2021-07-30  |NULL                                                                                              |
# |JD_RrDNNvMz|684547f470634603a66d8df4|2021-07-13   |2021-07-13  |Bachelor's degree in Business Administration, Information Technology, or a related field          |
# +-----------+------------------------+-------------+------------+--------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
# Total records: 6241
# Records after filtering nulls: 4378

# %%
from utils.silver_feature_extraction import extract_edu as U

# Save the education levels and fields as Parquet files
U.save_education_synonyms(spark, 'data/education_level_synonyms.parquet', U.education_levels)
U.save_education_synonyms(spark, 'data/education_field_synonyms.parquet', U.education_fields)

# %%
# Using rapidfuzz for fuzzy matching
from utils.edu_utils import determine_edu_mapping

# Collect and broadcast the education levels data
education_levels_list = spark.read.parquet('data/education_level_synonyms.parquet').collect()
edu_levels = spark.sparkContext.broadcast(education_levels_list)

# iterate through the DataFrame and apply the function
df_education = df_education.withColumn(
    'education_level',
    F.udf(lambda x: determine_edu_mapping(x, edu_levels.value), T.StringType())(F.col('required_education'))
)
df_education.show(10, truncate=False)
pyspark_df_info(df_education)
# Out:
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |job_id     |_id                     |snapshot_date|job_snapshot|required_education                                                                                                                      |education_level  |
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# |JD_Z7yf1tu6|684547e670634603a66d8deb|2021-07-24   |2021-07-24  |Bachelor's degree in computer science or a related discipline required. Master's degree preferred.                                      |Bachelor's Degree|
# |JD_RrDNNvMz|684547f470634603a66d8df4|2021-07-13   |2021-07-13  |Bachelor's degree in Business Administration, Information Technology, or a related field                                                |Bachelor's Degree|
# |JD_7rYoKTcb|684547fc70634603a66d8df9|2021-07-28   |2021-07-28  |bachelor's degree                                                                                                                       |Bachelor's Degree|
# |JD_AAwaK8NY|6845480970634603a66d8e01|2021-07-17   |2021-07-17  |Bachelors degree in accounting or finance (concentration in Accounting) preferred.                                                      |Master's Degree  |
# |JD_ZZpNAyeK|6845482370634603a66d8e12|2021-07-16   |2021-07-16  |BS Degree in computer science or related STEM field                                                                                     |Bachelor's Degree|
# |JD_kL06mNvW|6845483870634603a66d8e1f|2021-07-15   |2021-07-15  |Bachelor's degree or equivalent combination of education and experience (e.g., Master's + 1 year, or 7 years of related work experience)|Bachelor's Degree|
# |JD_gLmc70sy|6845483f70634603a66d8e24|2021-07-04   |2021-07-04  |Bachelor's degree in Computer Science, Engineering, or a related field                                                                  |Bachelor's Degree|
# |JD_WEgsEJYj|6845485370634603a66d8e31|2021-07-11   |2021-07-11  |B.S. in Computer Science or related field                                                                                               |Others           |
# |JD_fqhdZazg|6845486f70634603a66d8e43|2021-07-18   |2021-07-18  |BS/MS degree in Computer Science, Software Engineering, or related field                                                                |Master's Degree  |
# |JD_oG0yCZhW|6845487070634603a66d8e44|2021-07-02   |2021-07-02  |Bachelor's degree or equivalent experience                                                                                              |Bachelor's Degree|
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
#
# Total entries: 4378
# Data columns (total 6 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   job_id                    4378               string
# 1   _id                       4378               string
# 2   snapshot_date             4378               date
# 3   job_snapshot              4378               date
# 4   required_education        4378               string
# 5   education_level           4378               string
#
#
# 0   job_id                    4378               string
# 1   _id                       4378               string
# 2   snapshot_date             4378               date
# 3   job_snapshot              4378               date
# 4   required_education        4378               string
# 5   education_level           4378               string

# %%
# Using rapidfuzz for fuzzy matching
from utils.edu_utils import determine_edu_mapping

# Collect and broadcast the education levels data
education_fields_list = spark.read.parquet('data/education_field_synonyms.parquet').collect()
edu_fields = spark.sparkContext.broadcast(education_fields_list)

# iterate through the DataFrame and apply the function
df_education = df_education.withColumn(
    'education_field',
    F.udf(lambda x: determine_edu_mapping(x, edu_fields.value), T.StringType())(F.col('required_education'))
)
df_education.show(10, truncate=False)
pyspark_df_info(df_education)
# Out:
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+---------------------+
# |job_id     |_id                     |snapshot_date|job_snapshot|required_education                                                                                                                      |education_level  |education_field      |
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+---------------------+
# |JD_Z7yf1tu6|684547e670634603a66d8deb|2021-07-24   |2021-07-24  |Bachelor's degree in computer science or a related discipline required. Master's degree preferred.                                      |Bachelor's Degree|Computer Science & IT|
# |JD_RrDNNvMz|684547f470634603a66d8df4|2021-07-13   |2021-07-13  |Bachelor's degree in Business Administration, Information Technology, or a related field                                                |Bachelor's Degree|Business & Management|
# |JD_7rYoKTcb|684547fc70634603a66d8df9|2021-07-28   |2021-07-28  |bachelor's degree                                                                                                                       |Bachelor's Degree|Others               |
# |JD_AAwaK8NY|6845480970634603a66d8e01|2021-07-17   |2021-07-17  |Bachelors degree in accounting or finance (concentration in Accounting) preferred.                                                      |Master's Degree  |Finance & Accounting |
# |JD_ZZpNAyeK|6845482370634603a66d8e12|2021-07-16   |2021-07-16  |BS Degree in computer science or related STEM field                                                                                     |Bachelor's Degree|Computer Science & IT|
# |JD_kL06mNvW|6845483870634603a66d8e1f|2021-07-15   |2021-07-15  |Bachelor's degree or equivalent combination of education and experience (e.g., Master's + 1 year, or 7 years of related work experience)|Bachelor's Degree|Education & Training |
# |JD_gLmc70sy|6845483f70634603a66d8e24|2021-07-04   |2021-07-04  |Bachelor's degree in Computer Science, Engineering, or a related field                                                                  |Bachelor's Degree|Computer Science & IT|
# |JD_WEgsEJYj|6845485370634603a66d8e31|2021-07-11   |2021-07-11  |B.S. in Computer Science or related field                                                                                               |Others           |Computer Science & IT|
# |JD_fqhdZazg|6845486f70634603a66d8e43|2021-07-18   |2021-07-18  |BS/MS degree in Computer Science, Software Engineering, or related field                                                                |Master's Degree  |Computer Science & IT|
# |JD_oG0yCZhW|6845487070634603a66d8e44|2021-07-02   |2021-07-02  |Bachelor's degree or equivalent experience                                                                                              |Bachelor's Degree|Others               |
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+-----------------+---------------------+
# only showing top 10 rows
#
#
# Total entries: 4378
# Data columns (total 7 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   job_id                    4378               string
# 1   _id                       4378               string
# 2   snapshot_date             4378               date
# 3   job_snapshot              4378               date
# 4   required_education        4378               string
# 5   education_level           4378               string
# 6   education_field           4378               string
#
#
# 0   job_id                    4378               string
# 1   _id                       4378               string
# 2   snapshot_date             4378               date
# 3   job_snapshot              4378               date
# 4   required_education        4378               string
# 5   education_level           4378               string
# 6   education_field           4378               string

# %% [markdown]
# ## Education Level Parsing

# %%
df_education_levels = spark.createDataFrame(
    data=[
        ("High School", 1, "Completion of high school or equivalent", 
            [
                "high school", "ged", "secondary", "college", "diploma"
            ]
        ),
        ("Associate's Degree", 2, "Completion of a two-year degree program or certificate", 
            [
                "associate's", "a.a", "a.s", "a.a.s", "certificate"
            ]
        ),
        ("Bachelor's Degree", 3, "Completion of a undergraduate degree program", 
            [
                "bachelor", "bachelor's degree", "bachelor's in", "undergraduate degree",
                "ba", "bs", "bsc", "bba", "beng"
                
            ]
        ),
        ("Master's Degree", 4, "Completion of a postgraduate degree program", 
            [
                "master", "master's degree", "master's in", "postgraduate degree",
                "ma", "ms", "msc", "mba", "m.eng"
            ]
        ),
        ("Doctorate", 5, "Completion of a doctoral degree program", 
            [
                "phd", "md", "jd", "doctor", "doctorate", "doctorate degree", "doctoral degree"
            ]
        )
    ],
    schema=T.StructType([
        T.StructField('level_name', T.StringType(), False),
        T.StructField('level_scale', T.IntegerType(), False),
        T.StructField('level_description', T.StringType(), True),
        T.StructField('level_references', T.ArrayType(T.StringType()), True)
    ])
)

df_education_levels.show(5, truncate=False)
pyspark_df_info(df_education_levels)
# Save as Parquet instead of CSV
df_education_levels.write.mode('overwrite').parquet('data/education_level_synonyms_simplified.parquet')

# Read back from Parquet (preserves schema and array types)
df_education_levels = spark.read.parquet('data/education_level_synonyms_simplified.parquet')
pyspark_df_info(df_education_levels)
# Out:
# +------------------+-----------+------------------------------------------------------+------------------------------------------------------------------------------------------+
# |level_name        |level_scale|level_description                                     |level_references                                                                          |
# +------------------+-----------+------------------------------------------------------+------------------------------------------------------------------------------------------+
# |High School       |1          |Completion of high school or equivalent               |[high school, ged, secondary, college, diploma]                                           |
# |Associate's Degree|2          |Completion of a two-year degree program or certificate|[associate's, a.a, a.s, a.a.s, certificate]                                               |
# |Bachelor's Degree |3          |Completion of a undergraduate degree program          |[bachelor, bachelor's degree, bachelor's in, undergraduate degree, ba, bs, bsc, bba, beng]|
# |Master's Degree   |4          |Completion of a postgraduate degree program           |[master, master's degree, master's in, postgraduate degree, ma, ms, msc, mba, m.eng]      |
# |Doctorate         |5          |Completion of a doctoral degree program               |[phd, md, jd, doctor, doctorate, doctorate degree, doctoral degree]                       |
# +------------------+-----------+------------------------------------------------------+------------------------------------------------------------------------------------------+
#
#
# Total entries: 5
# Data columns (total 4 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   level_name                5                  string
# 1   level_scale               5                  int
# 2   level_description         5                  string
# 3   level_references          5                  array<string>
#
#
#
# Total entries: 5
# Data columns (total 4 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   level_name                5                  string
# 1   level_scale               5                  int
# 2   level_description         5                  string
# 3   level_references          5                  array<string>
#
#
#
# Total entries: 5
# Data columns (total 4 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   level_name                5                  string
# 1   level_scale               5                  int
# 2   level_description         5                  string
# 3   level_references          5                  array<string>

# %%
education_levels_list = spark.read.parquet('data/education_level_synonyms_simplified.parquet').collect()
broadcasted_education_levels = spark.sparkContext.broadcast(education_levels_list)

print(f"Broadcasted education levels: {len(broadcasted_education_levels.value)}")
print(f"Broadcasted education levels sample: \n{broadcasted_education_levels.value[:2]}")
# Out:
# Broadcasted education levels: 5
# Broadcasted education levels sample:
# [Row(level_name="Associate's Degree", level_scale=2, level_description='Completion of a two-year degree program or certificate', level_references=["associate's", 'a.a', 'a.s', 'a.a.s', 'certificate']), Row(level_name="Bachelor's Degree", level_scale=3, level_description='Completion of a undergraduate degree program', level_references=['bachelor', "bachelor's degree", "bachelor's in", 'undergraduate degree'])]

# %%
# Using rapidfuzz for fuzzy matching
from rapidfuzz import fuzz, process

# Collect and broadcast the education levels data
education_levels_list = spark.read.parquet('data/education_level_synonyms_simplified.parquet').collect()
broadcasted_education_levels = spark.sparkContext.broadcast(education_levels_list)

# For each entry in df_education, determine the education level by trying to match the required_education field with the level_references
def determine_education_level(education_input: str) -> int:
    if education_input is None:
        return None

    best_score = 0
    best_match_level = 0
    # Use rapidfuzz to find the best match
    for row in broadcasted_education_levels.value:
        match_result = process.extractOne(education_input.lower(), row.level_references, scorer=fuzz.partial_token_set_ratio)
        if match_result and match_result[1] > best_score:
            best_score, best_match_level = match_result[1], row.level_scale

    return best_match_level


# iterate through the DataFrame and apply the function
df_education = df_education.withColumn(
    'education_level',
    F.udf(determine_education_level, T.IntegerType())(F.col('required_education'))
)
df_education.show(10, truncate=False)
pyspark_df_info(df_education)
# Out:
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+---------------+
# |job_id     |_id                     |snapshot_date|job_snapshot|required_education                                                                                                                      |education_level|
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+---------------+
# |JD_Z7yf1tu6|684547e670634603a66d8deb|2021-07-24   |2021-07-24  |Bachelor's degree in computer science or a related discipline required. Master's degree preferred.                                      |3              |
# |JD_RrDNNvMz|684547f470634603a66d8df4|2021-07-13   |2021-07-13  |Bachelor's degree in Business Administration, Information Technology, or a related field                                                |3              |
# |JD_7rYoKTcb|684547fc70634603a66d8df9|2021-07-28   |2021-07-28  |bachelor's degree                                                                                                                       |3              |
# |JD_AAwaK8NY|6845480970634603a66d8e01|2021-07-17   |2021-07-17  |Bachelors degree in accounting or finance (concentration in Accounting) preferred.                                                      |3              |
# |JD_ZZpNAyeK|6845482370634603a66d8e12|2021-07-16   |2021-07-16  |BS Degree in computer science or related STEM field                                                                                     |3              |
# |JD_kL06mNvW|6845483870634603a66d8e1f|2021-07-15   |2021-07-15  |Bachelor's degree or equivalent combination of education and experience (e.g., Master's + 1 year, or 7 years of related work experience)|3              |
# |JD_gLmc70sy|6845483f70634603a66d8e24|2021-07-04   |2021-07-04  |Bachelor's degree in Computer Science, Engineering, or a related field                                                                  |3              |
# |JD_WEgsEJYj|6845485370634603a66d8e31|2021-07-11   |2021-07-11  |B.S. in Computer Science or related field                                                                                               |3              |
# |JD_fqhdZazg|6845486f70634603a66d8e43|2021-07-18   |2021-07-18  |BS/MS degree in Computer Science, Software Engineering, or related field                                                                |3              |
# |JD_oG0yCZhW|6845487070634603a66d8e44|2021-07-02   |2021-07-02  |Bachelor's degree or equivalent experience                                                                                              |3              |
# +-----------+------------------------+-------------+------------+----------------------------------------------------------------------------------------------------------------------------------------+---------------+
# only showing top 10 rows
#
#
# Total entries: 4378
# Data columns (total 6 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   job_id                    4378               string
# 1   _id                       4378               string
# 2   snapshot_date             4378               date
# 3   job_snapshot              4378               date
# 4   required_education        4378               string
# 5   education_level           4378               int

# %%
for l in range(1, 6):
    c = df_education.filter(F.col('education_level') == l).count()
    print(f"Count for education level {l}: {c}")
# Out:
# Count for education level 1: 78
# Count for education level 2: 30
# Count for education level 3: 3639
# Count for education level 4: 348
# Count for education level 3: 3639
# Count for education level 4: 348
# Count for education level 5: 283
# Count for education level 5: 283

# %% [markdown]
# ## Certification Parsing

# %%
df = spark.read.parquet('data/silver/*.parquet')
df_certifications = df.select('job_id', 'required_education', 'jd_certifications').filter(
    F.col('jd_certifications').isNotNull() & (F.size('jd_certifications') > 0)
)

pyspark_df_info(df_certifications)
df_certifications.show(5, truncate=False)
# Out:
# Total entries: 1778
# Data columns (total 3 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   job_id                    1778               string
# 1   required_education        1403               string
# 2   jd_certifications         1778               array<string>
#
#
# +-----------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |job_id     |required_education                                 |jd_certifications                                                                                                                                                         |
# +-----------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |JD_7rYoKTcb|bachelor's degree                                  |[PMP]                                                                                                                                                                     |
# |JD_dI74kKQw|NULL                                               |[Salesforce Certified Administrator, Salesforce Platform App Builder, Salesforce Platform Developer I, Salesforce Platform Developer II, Salesforce OMNI Studio Developer]|
# |JD_jxAmUMgn|NULL                                               |[Salesforce Certified Administrator, Salesforce Platform App Builder, Salesforce Platform Developer I, Salesforce Platform Developer II, Salesforce OMNI Studio Developer]|
# |JD_ZZpNAyeK|BS Degree in computer science or related STEM field|[AWS, Snowflake]                                                                                                                                                          |
# |JD_l7IXSfv7|NULL                                               |[Salesforce Certification]                                                                                                                                                |
# +-----------+---------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
# Explode the jd_certifications array to have one row per certification
df_exploded_certs = df_certifications.withColumn("certification", F.explode("jd_certifications"))

# Count the number of unique certifications
unique_certifications_count = df_exploded_certs.select("certification").distinct().count()

print(f"Number of unique certifications: {unique_certifications_count}")

# Show some of the unique certifications
print("Sample of unique certifications:")
df_exploded_certs.select("certification").distinct().show(150, truncate=False)
# Out:
# Number of unique certifications: 143
# Sample of unique certifications:
# +---------------------------------------------------------------------------------+
# |certification                                                                    |
# +---------------------------------------------------------------------------------+
# |Airflow                                                                          |
# |Ansible                                                                          |
# |Quickbooks Certified                                                             |
# |CSA (ServiceNow Certified System Administrator)                                  |
# |EA                                                                               |
# |AWS Certifications                                                               |
# |MLFlow                                                                           |
# |Salesforce Certification                                                         |
# |CPA (working towards certification)                                              |
# |SAFe                                                                             |
# |Docker                                                                           |
# |AWS                                                                              |
# |Salesforce OMNI Studio Developer                                                 |
# |Product Owner certification                                                      |
# |Maven                                                                            |
# |Salesforce Platform Developer I                                                  |
# |RunDeck                                                                          |
# |Kubernetes                                                                       |
# |CCM                                                                              |
# |EA (Enrolled Agent)                                                              |
# |Valid California Driver's License                                                |
# |Salesforce Certified Administrator                                               |
# |CPA (preferred, but not required)                                                |
# |NICCS Work Role ID: PR-VAM-001                                                   |
# |Oracle Cloud Applications                                                        |
# |Azure                                                                            |
# |DCMA                                                                             |
# |Databricks                                                                       |
# |CISSP                                                                            |
# |ASPICE                                                                           |
# |Certified Public Accountant (CPA)                                                |
# |HIPAA                                                                            |
# |Security+                                                                        |
# |CPA                                                                              |
# |Professional Engineer (PE) license                                               |
# |CAPM                                                                             |
# |CySA+                                                                            |
# |NICCS Work Role ID: AN-EXP-001                                                   |
# |Jenkins                                                                          |
# |Linux+                                                                           |
# |ISO26262                                                                         |
# |Teradata Big Data Analytics Certification                                        |
# |Google Cloud                                                                     |
# |Certification of Competency in Business Analysis (CCBA)                          |
# |EIT Certification in an energy-related field                                     |
# |Scrum Master certification                                                       |
# |SAFe Scrum Master                                                                |
# |CPA (Certified Public Accountant)                                                |
# |GCP                                                                              |
# |Salesforce Platform Developer II                                                 |
# |GICSP                                                                            |
# |Certified Business Analysis Professional (CBAP)                                  |
# |Grunt                                                                            |
# |Oracle Cloud Infrastructure                                                      |
# |California Driver's License                                                      |
# |Server+                                                                          |
# |Professional Engineer license                                                    |
# |AWS certifications                                                               |
# |PMP                                                                              |
# |CPA certification (preferred)                                                    |
# |CMA                                                                              |
# |CloudFormation                                                                   |
# |Snowflake                                                                        |
# |Git                                                                              |
# |Sisense                                                                          |
# |Salesforce Platform App Builder                                                  |
# |Scrum                                                                            |
# |DCAA                                                                             |
# |Power Automate                                                                   |
# |JDE Edwards                                                                      |
# |Product Owner                                                                    |
# |Professional Engineer license in Maryland                                        |
# |LabVIEW                                                                          |
# |Scrum Master                                                                     |
# |Industry recognized certifications                                               |
# |Terraform                                                                        |
# |CSA                                                                              |
# |Microsoft Dynamics 365                                                           |
# |Azure DevOps                                                                     |
# |SAFE Scrum Master                                                                |
# |CSA (Certified System Administrator)                                             |
# |SAP S4 (FI)                                                                      |
# |Microsoft Azure                                                                  |
# |Code Composer Studio (CCS)                                                       |
# |CPA (working towards)                                                            |
# |NetSuite                                                                         |
# |Angular                                                                          |
# |Certification or progress toward certification is highly preferred and encouraged|
# |Microsoft Certified: Azure Data Engineer Associate                               |
# |ETL (Airflow, Boomi)                                                             |
# |Salesforce                                                                       |
# |Xilinx FPGA                                                                      |
# |Notary                                                                           |
# |SAP R3                                                                           |
# |CE (Computer Environment) Linux+                                                 |
# |CGI Info Advantage Implementation (version 3.9, 3.10, or 3.11)                   |
# |Sage Intacct                                                                     |
# |Altera FPGA                                                                      |
# |AvidXchange                                                                      |
# |FloQast                                                                          |
# |BI Tools (Periscope, Sisense, Tableau)                                           |
# |C#                                                                               |
# |SSO                                                                              |
# |SAML                                                                             |
# |Visual Studio                                                                    |
# |JavaScript                                                                       |
# |Azure Service Bus                                                                |
# |jQuery                                                                           |
# |OpenId Connect                                                                   |
# |Mongo                                                                            |
# |SSIS                                                                             |
# |CANalyzer                                                                        |
# |Azure Storage                                                                    |
# |TypeScript                                                                       |
# |Professional Engineering (PE) license                                            |
# |Application Insights                                                             |
# |SAP R3 or S4 (FI)                                                                |
# |HTML                                                                             |
# |Entity Framework                                                                 |
# |.NET framework                                                                   |
# |Kendo                                                                            |
# |Boomi                                                                            |
# |CANoe                                                                            |
# |Azure Active Directory                                                           |
# |Tableau                                                                          |
# |WebAPI                                                                           |
# |Windows Server                                                                   |
# |WIF                                                                              |
# |CPA license                                                                      |
# |SQL Server                                                                       |
# |Azure App Services                                                               |
# |EIT Certification in an energy-related field (preferred)                         |
# |PE                                                                               |
# |CPA (preferred)                                                                  |
# |EIT                                                                              |
# |dbt                                                                              |
# |COPAS Accounting Procedure                                                       |
# |EIT Certification in an energy-related field (nice to have)                      |
# |Altera                                                                           |
# |Six Sigma                                                                        |
# |Code Composer Studio                                                             |
# |Xilinx                                                                           |
# |Design for Six Sigma                                                             |
# +---------------------------------------------------------------------------------+

# %%
from utils.silver_feature_extraction import extract_edu as U

# Save the certification categories as Parquet files
U.save_education_synonyms(spark, 'datamart/silver/education_ref/certification_categories.parquet', U.certification_categories)

# %%
from rapidfuzz import fuzz, process
from utils.silver_feature_extraction import extract_edu as U

def determine_certification_types(certification_arr: list[str], mapping: list, threshold: int=80) -> list:
    """
    Function to process list of certifications and determine their types.
    Args:
        certification_arr (list): List of certification objects.
        mapping (list): List of Row objects containing certification categories.
        threshold (int): Minimum score for fuzzy matching to consider a match valid.
    Returns:
        list: List of certification types.
    """
    if not certification_arr or len(certification_arr) == 0:
        return []
    certification_arr = [U._norm(c) for c in certification_arr if c]
    best_matches = set()
    for cert in certification_arr:
        for row in mapping:
            match_result = process.extractOne(query=cert, choices=row.group_references, scorer=fuzz.token_set_ratio)
            if match_result and match_result[1] > threshold:
                best_matches.add(", ".join([row.group_name, str(match_result[1])]))
    return list(best_matches)

# %%
# Collect and broadcast the education levels data
certification_list = spark.read.parquet('data/certification_categories.parquet').collect()
cert_categories = spark.sparkContext.broadcast(certification_list)

# iterate through the DataFrame and apply the function
df_certifications = df_certifications.withColumn(
    'required_certification_types',
    F.udf(lambda x: determine_certification_types(certification_arr=x, mapping=cert_categories.value), T.ArrayType(T.StringType()))(F.col('jd_certifications'))
)
df_certifications.show(10, truncate=False)
pyspark_df_info(df_certifications)
# Out:
# +-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+
# |job_id     |required_education                                                                                                                                                      |jd_certifications                                                                                                                                                         |required_certification_types                                 |
# +-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+
# |JD_7rYoKTcb|bachelor's degree                                                                                                                                                       |[PMP]                                                                                                                                                                     |[Agile & Project Management, 100.0, Business Analysis, 100.0]|
# |JD_dI74kKQw|NULL                                                                                                                                                                    |[Salesforce Certified Administrator, Salesforce Platform App Builder, Salesforce Platform Developer I, Salesforce Platform Developer II, Salesforce OMNI Studio Developer]|[ERP & Business Software, 100.0]                             |
# |JD_jxAmUMgn|NULL                                                                                                                                                                    |[Salesforce Certified Administrator, Salesforce Platform App Builder, Salesforce Platform Developer I, Salesforce Platform Developer II, Salesforce OMNI Studio Developer]|[ERP & Business Software, 100.0]                             |
# |JD_ZZpNAyeK|BS Degree in computer science or related STEM field                                                                                                                     |[AWS, Snowflake]                                                                                                                                                          |[Cloud Certifications, 100.0]                                |
# |JD_l7IXSfv7|NULL                                                                                                                                                                    |[Salesforce Certification]                                                                                                                                                |[ERP & Business Software, 100.0]                             |
# |JD_gLmc70sy|Bachelor's degree in Computer Science, Engineering, or a related field                                                                                                  |[AWS, Google Cloud, Azure]                                                                                                                                                |[System Administration, 100.0, Cloud Certifications, 100.0]  |
# |JD_oG0yCZhW|Bachelor's degree or equivalent experience                                                                                                                              |[Product Owner certification, Scrum Master certification]                                                                                                                 |[Agile & Project Management, 100.0, Business Analysis, 100.0]|
# |JD_VdnO9qXj|B.S. in Electrical Engineering, Computer Science, Cybersecurity, Information Technology, Software Engineering, Information Systems, Computer Engineering, or equivalent.|[NICCS Work Role ID: PR-VAM-001, NICCS Work Role ID: AN-EXP-001]                                                                                                          |[Legal & Regulatory, 100.0]                                  |
# |JD_A5FvpJbu|Bachelor's degree in Engineering, Physics, or Mathematics                                                                                                               |[EIT Certification in an energy-related field]                                                                                                                            |[Engineering & Technical, 100.0]                             |
# |JD_99gVyV7U|NULL                                                                                                                                                                    |[Salesforce Certification]                                                                                                                                                |[ERP & Business Software, 100.0]                             |
# +-----------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------+
# only showing top 10 rows
#
#
# Total entries: 1778
# Data columns (total 4 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   job_id                    1778               string
# 1   required_education        1403               string
# 2   jd_certifications         1778               array<string>
# 3   required_certification_types 1778               array<string>

# %% [markdown]
# ## All together:

# %%
# imports
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType, IntegerType, ArrayType
from pyspark.sql.functions import udf

from utils.silver_feature_extraction import extract_edu as U
# Re-read the original DataFrame
df = spark.read.parquet('data/silver/*.parquet')

# Broadcast the education levels, fields, and certification categories
edu_levels = spark.sparkContext.broadcast(spark.read.parquet('data/education_level_synonyms.parquet').collect())
edu_fields = spark.sparkContext.broadcast(spark.read.parquet('data/education_field_synonyms.parquet').collect())
cert_categories = spark.sparkContext.broadcast(spark.read.parquet('data/certification_categories.parquet').collect())

# Apply the UDFs to map the required education and certifications
df = (
    df
    .withColumn("required_edu_level", udf(lambda x: U.determine_edu_mapping(x, edu_levels.value), StringType())("required_education"))
    .withColumn("required_edu_field", udf(lambda x: U.determine_edu_mapping(x, edu_fields.value), StringType())("required_education"))
    .withColumn("required_cert_categories", udf(lambda x: U.determine_certification_types(x, cert_categories.value), ArrayType(StringType()))("jd_certifications"))
    .drop("required_education")
    .drop("jd_certifications")
)

# Show the final DataFrame
df.select("_id", "required_edu_level", "required_edu_field", "required_cert_categories").show(10, truncate=False)
pyspark_df_info(df)
# Out:
# +------------------------+------------------+---------------------+-----------------------------------------------+
# |_id                     |required_edu_level|required_edu_field   |required_cert_categories                       |
# +------------------------+------------------+---------------------+-----------------------------------------------+
# |6845479b07df3572368fc32c|NULL              |NULL                 |[]                                             |
# |684547e670634603a66d8deb|Bachelor's Degree |Computer Science & IT|[]                                             |
# |684547ed70634603a66d8def|NULL              |NULL                 |[]                                             |
# |684547f370634603a66d8df3|NULL              |NULL                 |[]                                             |
# |684547f470634603a66d8df4|Bachelor's Degree |Business & Management|[]                                             |
# |684547fc70634603a66d8df9|Bachelor's Degree |Others               |[Business Analysis, Agile & Project Management]|
# |684547ff70634603a66d8dfb|NULL              |NULL                 |[ERP & Business Software]                      |
# |6845480970634603a66d8e01|Master's Degree   |Finance & Accounting |[]                                             |
# |6845480a70634603a66d8e02|NULL              |NULL                 |[ERP & Business Software]                      |
# |6845481270634603a66d8e07|NULL              |NULL                 |[]                                             |
# +------------------------+------------------+---------------------+-----------------------------------------------+
# only showing top 10 rows
#
#
# Total entries: 6241
# Data columns (total 33 columns):
# #   Column                    Non-Null Count     Dtype
# --- ------------------------- ------------------ ---------------
# 0   resume_id                 6241               string
# 1   job_id                    6241               string
# 2   _id                       6241               string
# 3   fit                       6241               string
# 4   snapshot_date             6241               date
# 5   fit_score                 6241               double
# 6   company_name              3908               string
# 7   role_title                6046               string
# 8   employment_type           6196               string
# 9   job_location              4075               string
# 10  about_the_company         3664               string
# 11  job_responsibilities      6241               array<string>
# 12  required_hard_skills      6241               array<string>
# 13  required_soft_skills      6241               array<string>
# 14  required_language_proficiencies 6241               array<string>
# 15  required_work_authorization 1141               string
# 16  job_snapshot              6241               date
# 17  name                      237                string
# 18  location_preference       146                string
# 19  work_authorization        131                string
# 20  employment_type_preference 304                string
# 21  hard_skills               6241               array<string>
# 22  soft_skills               6241               array<string>
# 23  languages                 6241               array<string>
# 24  experience                6241               array<struct<role:string,company:string,date_start:string,date_end:string,role_description:string,snapshot_date:string,id:string>>
# 25  education                 6241               array<struct<degree:string,institution:string,date_start:string,date_end:string,grade:double,description:string,snapshot_date:string,id:string>>
# 26  resume_certifications     6241               array<string>
# 27  resume_snapshot           6241               string
# 28  YoE                       6126               float
# 29  exp_sim                   6241               float
# 30  required_edu_level        4378               string
# 31  required_edu_field        4378               string
# 32  required_cert_categories  6241               array<string>

# %% [markdown]
# ## Processing for resume data

# %%
df = spark.read.parquet('data/silver/*.parquet')

df.select('_id', 'snapshot_date', 'education').show(5, truncate=False)
# Out:
# +------------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |_id                     |snapshot_date|education                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +------------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |6845479b07df3572368fc32c|2021-07-15   |[{Master of Science, Rochester Institute of Technology, NULL, 2018-08-01T00:00:00, NULL, Telecommunications Engineering Technology, NULL, NULL}, {Bachelor of Engineering, St. Joseph Eng. College, NULL, 2012-06-01T00:00:00, NULL, Electrical & Electronics, NULL, NULL}, {High School (Higher Secondary Certificate), National College, NULL, 2008-01-01T00:00:00, NULL, NULL, NULL, NULL}, {Secondary School (Indian Certificate of Secondary Education), Ryan International School, NULL, 2006-01-01T00:00:00, NULL, NULL, NULL, NULL}]                                                                                                               |
# |684547e670634603a66d8deb|2021-07-24   |[{M.S, Syracuse University, NULL, 2009-06-01T00:00:00, 3.3299999237060547, Computer Science, NULL, NULL}, {Bachelor of Engineering, Osmania University, NULL, 2007-05-01T00:00:00, NULL, Computer Science, NULL, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |684547ed70634603a66d8def|2021-07-21   |[{NULL, New York Institute of Technology, NULL, NULL, NULL, Fine Arts coursework. Emphasis in Architectural Design. Arts Education coursework. Economics coursework. Computer Information Systems coursework. 2D and 3D design coursework., NULL, NULL}, {Certificate of Completion: CAD, Porter & Chester Institute, NULL, NULL, NULL, Emphasis on Automated Computer Aided Drafting. Coursework included Manual Drafting and Civil Engineering focus. Electrical, Mechanical and Structural Engineering coursework. Computer Information Systems coursework. Construction training. 2D and 3D design coursework. Course on Lighting Design., NULL, NULL}]|
# |684547f370634603a66d8df3|2021-07-30   |[{Master of Science, Pace University, Seidenberg School of CSIS, 2015-09-01T00:00:00, 2017-05-01T00:00:00, NULL, Information Systems, NULL, NULL}, {Bachelor of Engineering, Mumbai University, 2009-09-01T00:00:00, 2013-08-01T00:00:00, NULL, Electronics and Communication, NULL, NULL}]                                                                                                                                                                                                                                                                                                                                                                |
# |684547f470634603a66d8df4|2021-07-13   |[{Masters of Engineering Management, Northeastern University-Boston, MA, NULL, 2018-08-01T00:00:00, 3.700000047683716, Database Design and Management, Data Warehousing and Business Intelligence, Collection Storage and Retrieval of Data using R, Data Mining and Machine Learning using R, Probability and Statistics., NULL, NULL}, {Bachelors of Technology, Calicut University, NSS College, NULL, 2012-06-01T00:00:00, NULL, Instrumentation and Control Engineering, NULL, NULL}]                                                                                                                                                                 |
# +------------------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, udf
from pyspark.sql.types import StringType, ArrayType
from rapidfuzz import fuzz, process

from utils.silver_feature_extraction.extract_edu import parse_education_udf_factory, determine_certification_types, _norm

def determine_edu_mapping(education_input: str, mapping: list, threshold: int=30) -> str | None:
    """
    Determine the mapping for a given input string for possible education values (level/field).
    Uses fuzzy matching to find the best match from the provided mapping.
    Args:
        education_input (str): The input string to match against the mapping.
        mapping (list): A list of Row objects containing level_references and level_scale.
    Returns:
        str: The best matching value from the mapping, or None if no match is found.
    """
    if education_input is None or len(education_input) == 0:
        return None
    education_input = _norm(education_input)
    best_score = 0
    best_match = ""
    for row in mapping:
        match_result = process.extractOne(query=education_input, choices=row.group_references, scorer=fuzz.token_set_ratio)
        if match_result and match_result[1] > best_score:
            best_score, best_match = match_result[1], row.group_name
    return ", ".join([best_match, str(best_score)]) if best_score >= threshold else "Others"



df = spark.read.parquet('data/silver/*.parquet')

# Broadcast the education levels, fields, and certification categories
edu_levels = spark.sparkContext.broadcast(spark.read.parquet('data/education_level_synonyms.parquet').collect())
edu_fields = spark.sparkContext.broadcast(spark.read.parquet('data/education_field_synonyms.parquet').collect())
cert_categories = spark.sparkContext.broadcast(spark.read.parquet('data/certification_categories.parquet').collect())

_edu_udf = parse_education_udf_factory()
df = (
    df
    .withColumn("tmp_edu", _edu_udf("education"))
    .withColumn("edu_highest_level", udf(lambda x: determine_edu_mapping(x, edu_levels.value, 30), StringType())("tmp_edu.edu_desc"))
    .withColumn("edu_field", udf(lambda x: determine_edu_mapping(x, edu_fields.value, 70), StringType())("tmp_edu.edu_desc"))
    .withColumn("edu_gpa", col("tmp_edu.edu_gpa"))
    .withColumn("edu_institution", col("tmp_edu.edu_institution"))
    .withColumn("cert_categories", udf(lambda x: determine_certification_types(x, cert_categories.value, 80), ArrayType(StringType()))("resume_certifications"))
    .drop("tmp_edu")
    .drop("education")
    .drop("resume_certifications")

)

# Show the final DataFrame
df.select("_id", "edu_highest_level", "edu_field", "edu_gpa", "edu_institution", "cert_categories").show(10, truncate=False)
# Out:
# +------------------------+-------------------------------------+-----------------------------+-------+------------------------------------------+---------------+
# |_id                     |edu_highest_level                    |edu_field                    |edu_gpa|edu_institution                           |cert_categories|
# +------------------------+-------------------------------------+-----------------------------+-------+------------------------------------------+---------------+
# |6845479b07df3572368fc32c|Master's Degree, 100.0               |Engineering (General), 100.0 |NULL   |Rochester Institute of Technology         |[]             |
# |684547e670634603a66d8deb|Master's Degree, 100.0               |Computer Science & IT, 100.0 |3.33   |Syracuse University                       |[]             |
# |684547ed70634603a66d8def|Master's Degree, 30.769230769230774  |Arts & Creative Fields, 100.0|NULL   |New York Institute of Technology          |[]             |
# |684547f370634603a66d8df3|Master's Degree, 100.0               |Computer Science & IT, 100.0 |NULL   |Pace University, Seidenberg School of CSIS|[]             |
# |684547f470634603a66d8df4|Others                               |Engineering (General), 100.0 |3.7    |Northeastern University-Boston, MA        |[]             |
# |684547fc70634603a66d8df9|Doctorate, 36.36363636363637         |Engineering (General), 100.0 |3.6    |Northwestern Polytechnic University       |[]             |
# |684547ff70634603a66d8dfb|Bachelor's Degree, 100.0             |Others                       |NULL   |Columbia University                       |[]             |
# |6845480970634603a66d8e01|Bachelor's Degree, 100.0             |Business & Management, 100.0 |NULL   |University of Greenwich-Nairobi           |[]             |
# |6845480a70634603a66d8e02|Bachelor's Degree, 38.297872340425535|Engineering (General), 100.0 |NULL   |Florida International University          |[]             |
# |6845481270634603a66d8e07|Others                               |Finance & Accounting, 100.0  |3.5    |Friends University-Wichita                |[]             |
# +------------------------+-------------------------------------+-----------------------------+-------+------------------------------------------+---------------+
# only showing top 10 rows

# %%
# imports
from pyspark.sql.types import StringType, IntegerType, ArrayType
from pyspark.sql.functions import udf

from utils.silver_feature_extraction import extract_edu as U
# Re-read the original DataFrame
df = spark.read.parquet('data/silver/*.parquet')

# Broadcast the education levels, fields, and certification categories
edu_levels = spark.sparkContext.broadcast(spark.read.parquet('data/education_level_synonyms.parquet').collect())
edu_fields = spark.sparkContext.broadcast(spark.read.parquet('data/education_field_synonyms.parquet').collect())
cert_categories = spark.sparkContext.broadcast(spark.read.parquet('data/certification_categories.parquet').collect())

# Apply the UDFs to map the required education and certifications
df = (
    df
    .withColumn("required_edu_level", udf(lambda x: U.determine_edu_mapping(x, edu_levels.value), StringType())("required_education"))
    .withColumn("required_edu_field", udf(lambda x: U.determine_edu_mapping(x, edu_fields.value), StringType())("required_education"))
    .withColumn("required_cert_categories", udf(lambda x: U.determine_certification_types(x, cert_categories.value), ArrayType(StringType()))("jd_certifications"))
    .drop("required_education")
    .drop("jd_certifications")
)

# Show the final DataFrame
df.select("_id", "required_edu_level", "required_edu_field", "required_cert_categories").show(10, truncate=False)
pyspark_df_info(df)
